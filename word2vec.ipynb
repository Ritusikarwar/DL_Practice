# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors
import gensim.downloader as api

# %%
model = api.load("word2vec-google-news-300")
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
model.most_similar('studies')
# Out:
# [('study', 0.7211393117904663),
#  ('epidemiological_studies', 0.682817816734314),
#  ('epidemiologic_studies', 0.6279892921447754),
#  ('longitudinal_studies', 0.6242455840110779),
#  ('Studies', 0.6047295331954956),
#  ('observational_studies', 0.596670925617218),
#  ('research', 0.5861175060272217),
#  ('randomized_trials', 0.5814043283462524),
#  ('randomized_clinical_trials', 0.5707367062568665),
#  ('experiments', 0.5693682432174683)]

# %%
model.similarity('exam','studies')
# Out:
# np.float32(0.2910107)

# %%
model.doesnt_match(['exam','studies','burger'])
# Out:
# 'burger'

# %% [markdown]
# Arithmetic operations
