# %%
# %pip install langchain chromadb tiktoken pypdf langchain_huggingface langchain-community
# Out:
# Requirement already satisfied: langchain in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (1.3.9)
# Requirement already satisfied: chromadb in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (1.5.9)
# Requirement already satisfied: tiktoken in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (0.13.0)
# Requirement already satisfied: pypdf in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (6.13.3)
# Collecting langchain_huggingface
#   Downloading langchain_huggingface-1.2.2-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: langchain-community in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (0.4.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.6 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain) (1.4.7)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain) (1.2.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.4.6->langchain) (0.16.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.6->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph<1.3.0,>=1.2.4->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.4->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (15.0.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.6->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.6->langchain) (2.34.2)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.6->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (4.14.0)
# Requirement already satisfied: certifi in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.4->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: build>=1.0.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.5.0)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.49.0)
# Requirement already satisfied: numpy>=1.22.5 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (2.4.6)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (4.68.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (1.81.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (36.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (5.2.1)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb) (4.26.0)
# Requirement already satisfied: regex in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from tiktoken) (2026.5.9)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain_huggingface) (1.19.0)
# Requirement already satisfied: click>=8.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer>=0.9.0->chromadb) (0.0.4)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-community) (3.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.7 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-community) (1.0.8)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-community) (2.0.51)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.24.2)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-classic<2.0.0,>=1.0.7->langchain-community) (1.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic-settings>=2.0->chromadb) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.6->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.6->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-community) (3.5.2)
# Requirement already satisfied: pyproject_hooks in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: flatbuffers in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.63b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=10.11.0->chromadb) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=10.11.0->chromadb) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: httptools>=0.8.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Downloading langchain_huggingface-1.2.2-py3-none-any.whl (31 kB)
# Installing collected packages: langchain_huggingface
# Successfully installed langchain_huggingface-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain-chroma
# Out:
# Requirement already satisfied: langchain-chroma in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (1.1.0)
# Requirement already satisfied: chromadb<2.0.0,>=1.3.5 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-chroma) (1.5.9)
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-chroma) (1.4.7)
# Requirement already satisfied: numpy>=1.26.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-chroma) (2.4.6)
# Requirement already satisfied: build>=1.0.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.0)
# Requirement already satisfied: pydantic>=2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.13.4)
# Requirement already satisfied: pydantic-settings>=2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.14.1)
# Requirement already satisfied: pybase64>=1.4.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.49.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.15.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.27.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.42.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.42.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.42.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.23.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.51.1)
# Requirement already satisfied: tqdm>=4.65.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.68.3)
# Requirement already satisfied: overrides>=7.3.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (7.1.0)
# Requirement already satisfied: grpcio>=1.58.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.81.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.25.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (36.0.2)
# Requirement already satisfied: tenacity>=8.2.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (9.1.4)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.0.3)
# Requirement already satisfied: mmh3>=4.0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (5.2.1)
# Requirement already satisfied: orjson>=3.9.12 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.11.9)
# Requirement already satisfied: httpx>=0.27.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (15.0.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.26.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.0.17)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.8.16)
# Requirement already satisfied: packaging>=23.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (26.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.16.1)
# Requirement already satisfied: jsonpointer>=1.9 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.1.1)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (15.0.1)
# Requirement already satisfied: xxhash>=3.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (0.25.0)
# Requirement already satisfied: anyio in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.14.0)
# Requirement already satisfied: certifi in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.2)
# Requirement already satisfied: pyproject_hooks in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: colorama in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from build>=1.0.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.4.6)
# Requirement already satisfied: attrs>=22.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jsonschema>=4.19.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.5.1)
# Requirement already satisfied: six>=1.9.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.9.0.post0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.0.0)
# Requirement already satisfied: urllib3!=2.6.0,>=1.24.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.7.0)
# Requirement already satisfied: durationpy>=0.7 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.10)
# Requirement already satisfied: aiohttp<4.0.0,>=3.13.5 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.14.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from aiohttp<4.0.0,>=3.13.5->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.24.2)
# Requirement already satisfied: flatbuffers in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from onnxruntime>=1.14.1->chromadb<2.0.0,>=1.3.5->langchain-chroma) (6.33.6)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.75.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.42.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.42.1)
# Requirement already satisfied: opentelemetry-proto==1.42.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.42.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from opentelemetry-sdk>=1.2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.63b1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from pydantic-settings>=2.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.3->langchain-chroma) (3.4.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.19.0)
# Requirement already satisfied: click>=8.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer>=0.9.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.0.4)
# Requirement already satisfied: httptools>=0.8.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (0.8.0)
# Requirement already satisfied: watchfiles>=0.20 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb<2.0.0,>=1.3.5->langchain-chroma) (1.2.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb<2.0.0,>=1.3.5->langchain-chroma) (3.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_core.documents import Document

# %%
doc1=Document(page_content="This is the first document.", metadata={"source": "doc1"})
doc2=Document(page_content="This is the second document.", metadata={"source": "doc2"})
docs=[doc1, doc2]

# %%
pip install sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.6.0-py3-none-any.whl.metadata (18 kB)
# Collecting transformers<6.0.0,>=4.41.0 (from sentence-transformers)
#   Downloading transformers-5.12.1-py3-none-any.whl.metadata (33 kB)
# Requirement already satisfied: huggingface-hub>=0.23.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from sentence-transformers) (1.19.0)
# Collecting torch>=1.11.0 (from sentence-transformers)
#   Downloading torch-2.12.1-cp311-cp311-win_amd64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.20.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from sentence-transformers) (2.4.6)
# Collecting scikit-learn>=0.22.0 (from sentence-transformers)
#   Downloading scikit_learn-1.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Collecting scipy>=1.0.0 (from sentence-transformers)
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm>=4.0.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from sentence-transformers) (4.68.3)
# Requirement already satisfied: packaging>=20.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.5.9)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl.metadata (7.4 kB)
# Requirement already satisfied: typer in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.25.1)
# Collecting safetensors>=0.4.3 (from transformers<6.0.0,>=4.41.0->sentence-transformers)
#   Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: click>=8.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (3.29.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (2026.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (1.5.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from huggingface-hub>=0.23.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: anyio in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (4.14.0)
# Requirement already satisfied: certifi in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (3.18)
# Requirement already satisfied: h11>=0.16 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: shellingham>=1.3.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.0.4)
# Requirement already satisfied: colorama in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Collecting joblib>=1.4.0 (from scikit-learn>=0.22.0->sentence-transformers)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting narwhals>=2.0.1 (from scikit-learn>=0.22.0->sentence-transformers)
#   Downloading narwhals-2.22.1-py3-none-any.whl.metadata (15 kB)
# Collecting threadpoolctl>=3.5.0 (from scikit-learn>=0.22.0->sentence-transformers)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting setuptools<82 (from torch>=1.11.0->sentence-transformers)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.11.0->sentence-transformers)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.11.0->sentence-transformers)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Downloading sentence_transformers-5.6.0-py3-none-any.whl (596 kB)
#    ---------------------------------------- 0.0/596.4 kB ? eta -:--:--
#    ---------------------------------------- 596.4/596.4 kB 22.3 MB/s  0:00:00
# Downloading transformers-5.12.1-py3-none-any.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    -------------------------------------- - 10.7/11.2 MB 51.7 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 38.7 MB/s  0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    ---------------------- ----------------- 1.6/2.7 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.7/2.7 MB 7.6 MB/s  0:00:00
# Downloading safetensors-0.8.0-cp310-abi3-win_amd64.whl (355 kB)
# Downloading scikit_learn-1.9.0-cp311-cp311-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    --------------- ------------------------ 3.1/8.3 MB 15.4 MB/s eta 0:00:01
#    -------------------------------- ------- 6.8/8.3 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 13.9 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading narwhals-2.22.1-py3-none-any.whl (454 kB)
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
MB 15.2 MB/s eta 0:00:01
#    ------------------------------------- - 116.7/123.0 MB 15.1 MB/s eta 0:00:01
#    ------------------------------------- - 119.5/123.0 MB 15.0 MB/s eta 0:00:01
#    --------------------------------------  122.9/123.0 MB 15.1 MB/s eta 0:00:01
#    --------------------------------------  122.9/123.0 MB 15.1 MB/s eta 0:00:01
#    --------------------------------------  122.9/123.0 MB 15.1 MB/s eta 0:00:01
#    ---------------------------------------- 123.0/123.0 MB 14.0 MB/s  0:00:08
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 12.7 MB/s  0:00:00
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------- 2.1/2.1 MB 14.5 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    ------------------------------------ --- 5.8/6.3 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 22.8 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ---------------------------------------- 0.0/536.2 kB ? eta -:--:--
#    ---------------------------------------- 536.2/536.2 kB 18.3 MB/s  0:00:00
# Installing collected packages: mpmath, threadpoolctl, sympy, setuptools, scipy, safetensors, networkx, narwhals, joblib, torch, scikit-learn, tokenizers, transformers, sentence-transformers
#
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    ----------------------------------------  0/14 [mpmath]
#    -- -------------------------------------  1/14 [threadpoolctl]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#    ----- ----------------------------------  2/14 [sympy]
#   Attempting uninstall: setuptools
#    ----- ----------------------------------  2/14 [sympy]
#     Found existing installation: setuptools 82.0.1
#    ----- ----------------------------------  2/14 [sympy]
#     Uninstalling setuptools-82.0.1:
#    ----- ----------------------------------  2/14 [sympy]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#       Successfully uninstalled setuptools-82.0.1
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    -------- -------------------------------  3/14 [setuptools]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------- ----------------------------  4/14 [scipy]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    ----------------- ----------------------  6/14 [networkx]
#    -------------------- -------------------  7/14 [narwhals]
#    -------------------- -------------------  7/14 [narwhals]
#    -------------------- -------------------  7/14 [narwhals]
#    -------------------- -------------------  7/14 [narwhals]
#    -------------------- -------------------  7/14 [narwhals]
#    -------------------- -------------------  7/14 [narwhals]
#    ---------------------- -----------------  8/14 [joblib]
#    ---------------------- -----------------  8/14 [joblib]
#    ---------------------- -----------------  8/14 [joblib]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ------------------------- --------------  9/14 [torch]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ---------------------------- ----------- 10/14 [scikit-learn]
#   Attempting uninstall: tokenizers
#    ---------------------------- ----------- 10/14 [scikit-learn]
#     Found existing installation: tokenizers 0.23.1
#    ---------------------------- ----------- 10/14 [scikit-learn]
#     Uninstalling tokenizers-0.23.1:
#    ---------------------------- ----------- 10/14 [scikit-learn]
#       Successfully uninstalled tokenizers-0.23.1
#    ---------------------------- ----------- 10/14 [scikit-learn]
#    ------------------------------- -------- 11/14 [tokenizers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
# ...
# Requirement already satisfied: colorama in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from click>=8.4.0->huggingface-hub>=0.23.0->sentence-transformers) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<6.0.0,>=4.41.0->sentence-transformers) (0.1.2)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from scikit-learn>=0.22.0->sentence-transformers) (3.6.0)
# Requirement already satisfied: setuptools<82 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Using cached sentence_transformers-5.6.0-py3-none-any.whl (596 kB)
# Using cached transformers-5.12.1-py3-none-any.whl (11.2 MB)
# Using cached tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached scikit_learn-1.9.0-cp311-cp311-win_amd64.whl (8.3 MB)
# Installing collected packages: scikit-learn, tokenizers, transformers, sentence-transformers
#
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------------------------------------- 0/4 [scikit-learn]
#   Attempting uninstall: tokenizers
#    ---------------------------------------- 0/4 [scikit-learn]
#     Found existing installation: tokenizers 0.22.2
#    ---------------------------------------- 0/4 [scikit-learn]
#     Uninstalling tokenizers-0.22.2:
#    ---------------------------------------- 0/4 [scikit-learn]
#       Successfully uninstalled tokenizers-0.22.2
#    ---------------------------------------- 0/4 [scikit-learn]
#    ---------- ----------------------------- 1/4 [tokenizers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    -------------------- ------------------- 2/4 [transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ------------------------------ --------- 3/4 [sentence-transformers]
#    ---------------------------------------- 4/4 [sentence-transformers]
#
# Successfully installed scikit-learn-1.9.0 sentence-transformers-5.6.0 tokenizers-0.22.2 transformers-5.12.1
# Note: you may need to restart the kernel to use updated packages.

# %%
embedding_model=HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vector_store=Chroma(
    embedding_function=embedding_model,
    persist_directory="./chroma_db",
    collection_name="my_collection"
)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# c:\Users\Admin\miniconda3\envs\deepl\Lib\site-packages\huggingface_hub\file_download.py:137: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin\.cache\huggingface\hub\models--sentence-transformers--all-MiniLM-L6-v2. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
